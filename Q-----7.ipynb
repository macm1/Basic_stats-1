# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 250

# %%
df=pd.read_csv(r"C:\Users\mange\OneDrive\Documents\DS\Assignments\Q7.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\mange\Downloads\Basic_Stat_Level_2--Q1.xlsx")
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df.drop(columns=["Unnamed: 0"] , inplace=True)
df
# Out:
#     Points  Score  Weigh
# 0     3.90  2.620  16.46
# 1     3.90  2.875  17.02
# 2     3.85  2.320  18.61
# 3     3.08  3.215  19.44
# 4     3.15  3.440  17.02
# 5     2.76  3.460  20.22
# 6     3.21  3.570  15.84
# 7     3.69  3.190  20.00
# 8     3.92  3.150  22.90
# 9     3.92  3.440  18.30
# 10    3.92  3.440  18.90
# 11    3.07  4.070  17.40
# 12    3.07  3.730  17.60
# 13    3.07  3.780  18.00
# 14    2.93  5.250  17.98
# 15    3.00  5.424  17.82
# 16    3.23  5.345  17.42
# 17    4.08  2.200  19.47
# 18    4.93  1.615  18.52
# 19    4.22  1.835  19.90
# 20    3.70  2.465  20.01
# 21    2.76  3.520  16.87
# 22    3.15  3.435  17.30
# 23    3.73  3.840  15.41
# 24    3.08  3.845  17.05
# 25    4.08  1.935  18.90
# 26    4.43  2.140  16.70
# 27    3.77  1.513  16.90
# 28    4.22  3.170  14.50
# 29    3.62  2.770  15.50
# 30    3.54  3.570  14.60
# 31    4.11  2.780  18.60

# %%
np.mean(df , axis=0)
# Out:
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
np.median(df ,axis=0)
# Out:
# array([ 3.695,  3.325, 17.71 ])

# %%
df["Points"].mode()
# Out:
# 0    3.07
# 1    3.92
# Name: Points, dtype: float64

# %%
df["Score"].mode()
# Out:
# 0    3.44
# Name: Score, dtype: float64

# %%
df["Weigh"].mode()
# Out:
# 0    17.02
# 1    18.90
# Name: Weigh, dtype: float64

# %%
np.var(df , axis=0)
# Out:
# Points    0.276948
# Score     0.927461
# Weigh     3.093380
# dtype: float64

# %%
np.std(df , axis=0)
# Out:
# Points    0.526258
# Score     0.963048
# Weigh     1.758801
# dtype: float64

# %%
# PTP = peak to peak (Range) i.e (max - min )

np.ptp(df , axis=0)
# Out:
# Points    2.170
# Score     3.911
# Weigh     8.400
# dtype: float64

# %%
df.boxplot()
# Out:
# <Axes: >
